# %%
### dependecies ###
import pandas as pd 
import numpy as np
import data_preparation as dp
import os
import matplotlib.pyplot as plt

# %%
data_left = pd.read_csv(
        #r"W:\WCT\04_Mind-Wandering-Labstudy\04_Daten\04_Prepared_data\00_Julia\summary_statistics_left_eye_all_participants.txt",
        r"W:\WCT\04_Mind-Wandering-Labstudy\04_Daten\04_Prepared_data\00_Julia\left_eye_without_excluded_participant_trackingratio_over70.csv",
        na_values = "-"
    )

data_right_ohne_ratio = pd.read_csv(
        #r"W:\WCT\04_Mind-Wandering-Labstudy\04_Daten\04_Prepared_data\00_Julia\summary_statistics_left_eye_all_participants.txt",
        r"W:\WCT\04_Mind-Wandering-Labstudy\04_Daten\04_Prepared_data\00_Julia\right_eye_without_excluded_participant.csv",
        na_values = "-"
    )

data_right =  pd.read_csv(
        #r"W:\WCT\04_Mind-Wandering-Labstudy\04_Daten\04_Prepared_data\00_Julia\summary_statistics_left_eye_all_participants.txt",
        r"W:\WCT\04_Mind-Wandering-Labstudy\04_Daten\04_Prepared_data\00_Julia\right_eye_without_excluded_participant_trackingratio_over70.csv",
        na_values = "-"
    )

data_left_ohne_ratio =  pd.read_csv(
        #r"W:\WCT\04_Mind-Wandering-Labstudy\04_Daten\04_Prepared_data\00_Julia\summary_statistics_left_eye_all_participants.txt",
        r"W:\WCT\04_Mind-Wandering-Labstudy\04_Daten\04_Prepared_data\00_Julia\left_eye_without_excluded_participant.csv",
        na_values = "-"
    )

# %%
c = data_right_ohne_ratio.loc[data_right_ohne_ratio["Tracking Ratio [%] Mean"] != data_left_ohne_ratio["Tracking Ratio [%] Mean"]]
x = c.columns


#warum ist das hier unterschiedlich?
# Out:
# Index(['Tracking Ratio [%] Mean', 'Stimulus', 'Participant',
#        'Fixation Duration Mean [ms]', 'Fixation Duration Max [ms]',
#        'Fixation Duration Min [ms]', 'Fixation Duration Median [ms]',
#        'Fixation Duration Std [ms]', 'Fixation Duration Skew [ms]',
#        'Fixation Duration Quantil 25 [ms]',
#        ...
#        'Saccade Length Kurtosis [px]',
#        'Fixation Average Pupil Diameter [mm] Mean',
#        'Fixation Average Pupil Diameter [mm] Max',
#        'Fixation Average Pupil Diameter [mm] Min',
#        'Fixation Average Pupil Diameter [mm] Median',
#        'Fixation Average Pupil Diameter [mm] Std',
#        'Fixation Average Pupil Diameter [mm] Skew',
#        'Fixation Average Pupil Diameter [mm] Quantil25',
#        'Fixation Average Pupil Diameter [mm] Quantil75',
#        'Fixation Average Pupil Diameter [mm] Kurtosis'],
#       dtype='object', length=138)

# %%
data_left_ohne_ratio.loc[data_left_ohne_ratio["Tracking Ratio [%] Mean"] >= 70.0]
# Out:
#       Tracking Ratio [%] Mean Stimulus Participant  \
# 0                      85.268     vid1           1
# 1                      81.388    vid10           1
# 2                      83.450    vid11           1
# 3                      83.736    vid12           1
# 4                      87.020    vid13           1
# ...                       ...      ...         ...
# 1075                   91.360     vid5          97
# 1076                   96.044     vid6          97
# 1077                   86.734     vid7          97
# 1078                   87.880     vid8          97
# 1079                   84.449     vid9          97
#
#       Fixation Duration Mean [ms]  Fixation Duration Max [ms]  \
# 0                      252.982821                     664.007
# 1                      195.286941                     748.002
# 2                      182.768333                     555.851
# 3                      309.427091                    1004.021
# 4                      481.714250                    1199.827
# ...                           ...                         ...
# 1075                   563.936600                    2703.548
# 1076                   718.957333                    3295.693
# 1077                   342.338227                     931.766
# 1078                   362.136250                     916.068
# 1079                   462.098471                    1983.980
#
#       Fixation Duration Min [ms]  Fixation Duration Median [ms]  \
# 0                         71.976                       256.0930
# 1                         59.932                       147.9960
# 2                         51.933                       144.1760
# 3                         71.995                       209.9450
# 4                        112.038                       305.9685
# ...                          ...                            ...
# 1075                     119.888                       208.0190
# 1076                      87.976                       245.9740
# 1077                     103.999                       249.8595
# 1078                     100.024                       261.9140
# 1079                      63.945                       232.0230
#
#       Fixation Duration Std [ms]  Fixation Duration Skew [ms]  \
# 0                     144.760085                     1.280309
# 1                     140.177478                     2.312305
# 2                     105.519199                     1.716069
# 3                     263.363851                     1.824642
# 4                     386.935147                     1.082098
# ...                          ...                          ...
# 1075                  868.164843                     2.278798
# 1076                 1018.499256                     1.995014
# 1077                  232.367807                     1.363910
# 1078                  243.940942                     1.160998
# 1079                  512.773094                     2.111301
#
#       Fixation Duration Quantil 25 [ms]  ...  Saccade Length Kurtosis [px]  \
# 0                             155.98500  ...                      3.371654
# 1                             112.02150  ...                      0.431686
# 2                             108.12700  ...                      9.855421
# 3                             168.87025  ...                      1.505145
# 4                             191.08225  ...                     -1.249834
# ...                                 ...  ...                           ...
# 1075                          145.99900  ...                     -1.075502
# 1076                          184.18575  ...                      3.899080
# 1077                          181.94575  ...                      0.763580
# 1078                          194.97000  ...                      3.649546
# 1079                          179.98400  ...                      4.742785
#
#       Fixation Average Pupil Diameter [mm] Mean  \
# 0                                     -1.127818
# 1                                     -1.270185
# 2                                     -0.931780
# 3                                     -0.959977
# 4                                     -0.945505
# ...                                         ...
# 1075                                  -0.264928
# 1076                                  -0.247711
# 1077                                  -0.367006
# 1078                                  -0.252753
# 1079                                  -0.359284
#
#       Fixation Average Pupil Diameter [mm] Max  \
# 0                                    -0.925568
# 1                                    -0.958568
# 2                                    -0.595568
# 3                                    -0.499568
# 4                                    -0.772568
# ...                                        ...
# 1075                                 -0.100461
# 1076                                 -0.130461
# 1077                                 -0.241461
# 1078                                 -0.009461
# 1079                                 -0.114461
#
#       Fixation Average Pupil Diameter [mm] Min  \
# 0                                    -1.434568
# 1                                    -1.544568
# 2                                    -2.813568
# 3                                    -2.751568
# 4                                    -1.100568
# ...                                        ...
# 1075                                 -0.434461
# 1076                                 -0.308461
# 1077                                 -0.432461
# 1078                                 -0.456461
# 1079                                 -0.499461
#
#       Fixation Average Pupil Diameter [mm] Median  \
# 0                                       -1.064068
# 1                                       -1.284068
# 2                                       -0.890568
# 3                                       -0.866068
# 4                                       -0.932568
# ...                                           ...
# 1075                                    -0.272461
# 1076                                    -0.272961
# 1077                                    -0.384461
# 1078                                    -0.249461
# 1079                                    -0.385461
#
#       Fixation Average Pupil Diameter [mm] Std  \
# 0                                     0.148843
# 1                                     0.151514
# 2                                     0.355267
# 3                                     0.450501
# 4                                     0.084503
# ...                                        ...
# 1075                                  0.120788
# 1076                                  0.060885
# 1077                                  0.054336
# 1078                                  0.123787
# 1079                                  0.108494
#
#       Fixation Average Pupil Diameter [mm] Skew  \
# 0                                     -0.775103
# 1                                      0.198931
# 2                                     -4.862128
# 3                                     -3.155816
# 4                                     -0.077990
# ...                                         ...
# 1075                                   0.141741
# 1076                                   0.889884
# 1077                                   0.903413
# 1078                                   0.232176
# 1079                                   1.140345
#
#       Fixation Average Pupil Diameter [mm] Quantil25  \
# 0                                          -1.252568
# 1                                          -1.346818
# 2                                          -0.963568
# 3                                          -1.086068
# 4                                          -0.989818
# ...                                              ...
# 1075                                       -0.374961
# 1076                                       -0.294961
# 1077                                       -0.404711
# 1078                                       -0.344211
# 1079                                       -0.417461
#
#       Fixation Average Pupil Diameter [mm] Quantil75  \
# 0                                          -1.019318
# 1                                          -1.205318
# 2                                          -0.839568
# 3                                          -0.756068
# 4                                          -0.909068
# ...                                              ...
# 1075                                       -0.147461
# 1076                                       -0.209961
# 1077                                       -0.340711
# 1078                                       -0.184961
# 1079                                       -0.335461
#
#       Fixation Average Pupil Diameter [mm] Kurtosis
# 0                                         -0.575875
# 1                                         -0.262884
# 2                                         26.448884
# 3                                         12.570896
# 4                                          0.162517
# ...                                             ...
# 1075                                      -1.572003
# 1076                                      -0.570374
# 1077                                      -0.187710
# 1078                                      -0.518603
# 1079                                       0.710067
#
# [862 rows x 138 columns]

# %%
data_right_ohne_ratio[data_right_ohne_ratio["Tracking Ratio [%] Mean"] >= 70.0]
# Out:
#       Tracking Ratio [%] Mean Stimulus Participant  \
# 0                      85.268     vid1           1
# 1                      81.388    vid10           1
# 2                      83.450    vid11           1
# 3                      83.736    vid12           1
# 4                      87.020    vid13           1
# ...                       ...      ...         ...
# 1075                   91.360     vid5          97
# 1076                   96.044     vid6          97
# 1077                   86.734     vid7          97
# 1078                   87.880     vid8          97
# 1079                   84.449     vid9          97
#
#       Fixation Duration Mean [ms]  Fixation Duration Max [ms]  \
# 0                      266.803333                     672.000
# 1                      195.291500                     728.016
# 2                      225.713000                     943.889
# 3                      314.333045                    1004.019
# 4                      485.958813                    1207.828
# ...                           ...                         ...
# 1075                   562.869867                    2695.546
# 1076                   660.884154                    3303.688
# 1077                   375.349895                     927.763
# 1078                   332.587962                     895.798
# 1079                   414.877778                    1184.169
#
#       Fixation Duration Min [ms]  Fixation Duration Median [ms]  \
# 0                         87.945                       235.9320
# 1                         59.955                       140.0120
# 2                         76.004                       185.9325
# 3                         59.961                       202.0625
# 4                        111.895                       317.9900
# ...                          ...                            ...
# 1075                      95.998                       208.0190
# 1076                      83.978                       263.8950
# 1077                     100.000                       243.9200
# 1078                      96.024                       252.0410
# 1079                      55.963                       236.0270
#
#       Fixation Duration Std [ms]  Fixation Duration Skew [ms]  \
# 0                     152.914011                     1.271002
# 1                     138.464647                     2.234923
# 2                     167.914402                     3.123432
# 3                     270.148766                     1.645880
# 4                     381.123027                     1.101017
# ...                          ...                          ...
# 1075                  868.955092                     2.275067
# 1076                  903.929068                     2.445542
# 1077                  264.307047                     0.909590
# 1078                  203.793842                     1.374261
# 1079                  373.692698                     1.470471
#
#       Fixation Duration Quantil 25 [ms]  ...  Saccade Length Kurtosis [px]  \
# 0                             155.98550  ...                     -0.848155
# 1                             115.94325  ...                     -0.165805
# 2                             137.05175  ...                      2.999593
# 3                             146.00400  ...                      3.861385
# 4                             208.07700  ...                     -1.927420
# ...                                 ...  ...                           ...
# 1075                          153.97000  ...                     -1.004752
# 1076                          192.09500  ...                      4.594224
# 1077                          169.95100  ...                      5.607970
# 1078                          201.01350  ...                      4.156504
# 1079                          193.03050  ...                      5.243339
#
#       Fixation Average Pupil Diameter [mm] Mean  \
# 0                                     -0.881345
# 1                                     -0.902362
# 2                                     -0.483334
# 3                                     -0.551795
# 4                                     -0.509818
# ...                                         ...
# 1075                                  -0.218328
# 1076                                  -0.228845
# 1077                                  -0.360566
# 1078                                  -0.209922
# 1079                                  -0.373683
#
#       Fixation Average Pupil Diameter [mm] Max  \
# 0                                    -0.575568
# 1                                    -0.685568
# 2                                    -0.329568
# 3                                    -0.068568
# 4                                    -0.334568
# ...                                        ...
# 1075                                 -0.009461
# 1076                                 -0.051461
# 1077                                 -0.209461
# 1078                                  0.015539
# 1079                                 -0.210461
#
#       Fixation Average Pupil Diameter [mm] Min  \
# 0                                    -1.170568
# 1                                    -1.237568
# 2                                    -0.990568
# 3                                    -2.548568
# 4                                    -0.718568
# ...                                        ...
# 1075                                 -0.432461
# 1076                                 -0.305461
# 1077                                 -0.506461
# 1078                                 -0.424461
# 1079                                 -0.526461
#
#       Fixation Average Pupil Diameter [mm] Median  \
# 0                                       -0.860568
# 1                                       -0.858568
# 2                                       -0.473568
# 3                                       -0.532068
# 4                                       -0.477068
# ...                                           ...
# 1075                                    -0.207461
# 1076                                    -0.252461
# 1077                                    -0.357461
# 1078                                    -0.179461
# 1079                                    -0.377461
#
#       Fixation Average Pupil Diameter [mm] Std  \
# 0                                     0.138252
# 1                                     0.158408
# 2                                     0.122049
# 3                                     0.486959
# 4                                     0.116855
# ...                                        ...
# 1075                                  0.133607
# 1076                                  0.069870
# 1077                                  0.075000
# 1078                                  0.144185
# 1079                                  0.108114
#
#       Fixation Average Pupil Diameter [mm] Skew  \
# 0                                     -0.003070
# 1                                     -0.687891
# 2                                     -2.456564
# 3                                     -3.465804
# 4                                     -0.650511
# ...                                         ...
# 1075                                   0.094565
# 1076                                   1.484260
# 1077                                   0.243440
# 1078                                  -0.079669
# 1079                                   0.097473
#
#       Fixation Average Pupil Diameter [mm] Quantil25  \
# 0                                          -1.004068
# 1                                          -1.001068
# 2                                          -0.534318
# 3                                          -0.598818
# 4                                          -0.582818
# ...                                              ...
# 1075                                       -0.336461
# 1076                                       -0.271461
# 1077                                       -0.396961
# 1078                                       -0.353461
# 1079                                       -0.474211
#
#       Fixation Average Pupil Diameter [mm] Quantil75  \
# 0                                          -0.817568
# 1                                          -0.798068
# 2                                          -0.410068
# 3                                          -0.293568
# 4                                          -0.447818
# ...                                              ...
# 1075                                       -0.113961
# 1076                                       -0.199461
# 1077                                       -0.338461
# 1078                                       -0.084711
# 1079                                       -0.270211
#
#       Fixation Average Pupil Diameter [mm] Kurtosis
# 0                                         -0.219804
# 1                                         -0.475305
# 2                                          9.775394
# 3                                         14.603407
# 4                                         -0.590138
# ...                                             ...
# 1075                                      -1.263062
# 1076                                       2.462689
# 1077                                       0.225135
# 1078                                      -1.638953
# 1079                                      -1.367074
#
# [865 rows x 138 columns]

# %%
### how many videos are left? 
#left eye
data_left.groupby("Participant").count()["Tracking Ratio [%] Mean"].plot(kind = "bar", title = "Videos per Participant after excluding Videos, left eye", figsize = (15,5))
# Out:
# <AxesSubplot: title={'center': 'Videos per Participant after excluding Videos, left eye'}, xlabel='Participant'>

# %%
data_left_ohne_ratio.groupby("Participant").count()["Tracking Ratio [%] Mean"].plot(kind = "bar", title = "Videos per Participant, left eye", figsize = (15,5))
# Out:
# <AxesSubplot: title={'center': 'Videos per Participant, left eye'}, xlabel='Participant'>

# %%
# right eye
data_right.groupby("Participant").count()["Tracking Ratio [%] Mean"].plot(kind = "bar", title = "Videos per Participant after excluding Videos, right eye", figsize = (15,5))
# Out:
# <AxesSubplot: title={'center': 'Videos per Participant after excluding Videos, right eye'}, xlabel='Participant'>

# %%
data_right_ohne_ratio.groupby("Participant").count()["Tracking Ratio [%] Mean"].plot(kind = "bar", title = "Videos per Participant, right eye", figsize = (15,5))
# Out:
# <AxesSubplot: title={'center': 'Videos per Participant, right eye'}, xlabel='Participant'>

# %%
#### Histogram für ausgeschlossene Videos
order = ["vid1","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9", "vid10","vid11","vid12","vid13","vid14","vid15"]
data_right_ohne_ratio.loc[data_right_ohne_ratio["Tracking Ratio [%] Mean"] < 70.0].groupby('Stimulus').count().reset_index().set_index("Stimulus").loc[order]["Tracking Ratio [%] Mean"].plot(kind='bar',  title = "Ausgeschlossene Videos rechtes Auge")
# Out:
# <AxesSubplot: title={'center': 'Ausgeschlossene Videos rechtes Auge'}, xlabel='Stimulus'>

# %%
order = ["vid1","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9", "vid10","vid11","vid12","vid13","vid14","vid15"]
data_left_ohne_ratio.loc[data_left_ohne_ratio["Tracking Ratio [%] Mean"] < 70.0].groupby('Stimulus').count().reset_index().set_index("Stimulus").loc[order]["Tracking Ratio [%] Mean"].plot(kind='bar',  title = "Ausgeschlossene Videos linkes Auge")
# Out:
# <AxesSubplot: title={'center': 'Ausgeschlossene Videos linkes Auge'}, xlabel='Stimulus'>

# %%
#### Histogram für bestehende Videos
order = ["vid1","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9", "vid10","vid11","vid12","vid13","vid14","vid15"]
data_right.groupby('Stimulus').count().reset_index().set_index("Stimulus").loc[order]["Tracking Ratio [%] Mean"].plot(kind='bar',  title = "Verwendbare Videos rechtes Auge")
# Out:
# <AxesSubplot: title={'center': 'Verwendbare Videos rechtes Auge'}, xlabel='Stimulus'>

# %%
#### Histogram für bestehende Videos
order = ["vid1","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9", "vid10","vid11","vid12","vid13","vid14","vid15"]
data_left.groupby('Stimulus').count().reset_index().set_index("Stimulus").loc[order]["Tracking Ratio [%] Mean"].plot(kind='bar',  title = "Verwendbare Videos linkes Auge")
# Out:
# <AxesSubplot: title={'center': 'Verwendbare Videos linkes Auge'}, xlabel='Stimulus'>

# %%
# histogram how which an d how many videosa are excluded
data_left.groupby("Stimulus").hist()#.plot(kind = "hist", title = "Mean Blink Number per Video")

# %%
#one participants

# 1. look at whole dataframe and count the blinks per video
def count_blinks_whole_data(df_use):
    
    df_groups_sti_cat = df_use.groupby(["Stimulus", "Category"]) 
    return df_groups_sti_cat.count()["Trial"][:, "Blink"]

# %%
# 2. count blinks with a threshold per video
def count_blinks_theshold(df_use):
    df_left_eye =  dp.df_prepare_eye_tracking_data(df_use)[0]
    df_groups_sti_cat_left_eye = df_left_eye.groupby(["Stimulus", "Category"]) 
    return df_groups_sti_cat_left_eye.count()["Trial"][:, "Blink"]

# %%
# 3. count blinks in the last 10 seconds per video
def count_blinks_last_10_sek(df_use):
    df_10_sec_of_videos = dp.cut_last_10sec_of_videos(df_use)
    df_groups_sti_cat_last_10sec = df_10_sec_of_videos.groupby(["Stimulus", "Category"]) 
    return df_groups_sti_cat_last_10sec.count()["Trial"][:, "Blink"]

# %%
# 4. count blinks in last 10 seconds and with threshold per video
def count_blink_in_10sek_threshold(df_use):
    print(df_use)
    data = dp.df_prepare_eye_tracking_data(df_use)[0]
    df_10_sec_of_videos_threshold = dp.cut_last_10sec_of_videos(data)
    df_groups_sti_cat_last_10sec_threshold = df_10_sec_of_videos_threshold.groupby(["Stimulus", "Category"]) 
    return df_groups_sti_cat_last_10sec_threshold.count()["Trial"][:, "Blink"]

# %%
os.chdir("C:/Users/Julia/Desktop/Daten-BA/SMI_Eventstatistics") 
 #get all files in directory
list = os.listdir() 
 # remove participants
list.remove("Event Statistics - Single - 82.txt")
# remove excluded participants from validation Data and Erhebungsprotokoll
excluded_participants_ids = [2, 8, 11, 12, 13, 24, 25, 27, 30, 31, 38, 41, 43, 47, 50, 52, 54, 59, 63, 69, 70, 75, 82, 84, 89, 91, 101, 102, 103, 104, 105, 999
, 54, 56] #no data 
excluded_participants_filenname = []
for i in excluded_participants_ids:
    excluded_participants_filenname.append("Event Statistics - Single - " + str(i) +".txt")
list_without_excluded = [x for x in list if x not in excluded_participants_filenname]
list_without_excluded.remove('Event Statistics - Single - 02.txt')
list_without_excluded.remove('Event Statistics - Single - 08.txt')

blinks_left_eye_all_participants = pd.DataFrame()
list = ["Event Statistics - Single - 54.txt"]
for filename in list_without_excluded:
    print(filename)
    # input: filename # output: dataframe to work on
    df = dp.read_data(filename)
    df_use = df.loc[df["Tracking Ratio [%]"] >= 70.0]
    df_blinks = pd.DataFrame(index = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15", "vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"])
    df_blinks["Blink Number whole dataframe"] = count_blinks_whole_data(df_use).loc["vid1":"vid9"]
    df_blinks["Blink Number with threshold"] =  count_blinks_theshold(df_use).loc["vid1":"vid9"]
    df_blinks["Blink Number last 10 sec"] = count_blinks_last_10_sek(df_use).loc["vid1":"vid9"]
    df_blinks["Blinks of last 10 sec per video and threshold"] = count_blink_in_10sek_threshold(df_use).loc["vid1":"vid9"]
    df_blinks["Participant"] = [df.loc[:,"Participant"].values[0]] * 16
    df_blinks["Stimulus"] = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15", "vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
    
    blinks_left_eye_all_participants = pd.concat([blinks_left_eye_all_participants, df_blinks])
blinks_left_eye_all_participants

# %%
blinks_left_eye_all_participants
# Out:
#        Blink Number whole dataframe  Blink Number with threshold  \
# vid1                          306.0                        152.0
# vid10                         350.0                        164.0
# vid11                         141.0                         67.0
# vid12                         390.0                        200.0
# vid13                         241.0                        117.0
# ...                             ...                          ...
# vid5                          124.0                         51.0
# vid6                           31.0                         13.0
# vid7                          205.0                         79.0
# vid8                           92.0                         35.0
# vid9                          160.0                         51.0
#
#        Blink Number last 10 sec  \
# vid1                       14.0
# vid10                      12.0
# vid11                       9.0
# vid12                      11.0
# vid13                      14.0
# ...                         ...
# vid5                        6.0
# vid6                        4.0
# vid7                       10.0
# vid8                        2.0
# vid9                        7.0
#
#        Blinks of last 10 sec per video and threshold Participant Stimulus
# vid1                                             7.0           1     vid1
# vid10                                            6.0           1    vid10
# vid11                                            3.0           1    vid11
# vid12                                            4.0           1    vid12
# vid13                                            7.0           1    vid13
# ...                                              ...         ...      ...
# vid5                                             3.0          97     vid5
# vid6                                             2.0          97     vid6
# vid7                                             5.0          97     vid7
# vid8                                             1.0          97     vid8
# vid9                                             2.0          97     vid9
#
# [1136 rows x 6 columns]

# %%
#blinks_left_eye_all_participants.groupby("Stimulus").mean().plot(kind = "bar", title = "Mean Blink Number per Video")
order = ["vid1","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9", "vid10","vid11","vid12","vid13","vid14","vid15"]
blinks_left_eye_all_participants.groupby("Stimulus").mean().reset_index().set_index("Stimulus").loc[order].plot(kind = "bar", title = "Mean Blink Number per Video")
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_42816\3610233643.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   blinks_left_eye_all_participants.groupby("Stimulus").mean().reset_index().set_index("Stimulus").loc[order].plot(kind = "bar", title = "Mean Blink Number per Video")
# <AxesSubplot: title={'center': 'Mean Blink Number per Video'}, xlabel='Stimulus'>

# %%
order = ["vid1","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9", "vid10","vid11","vid12","vid13","vid14","vid15"]
blinks_left_eye_all_participants.groupby("Stimulus").mean()[["Blink Number last 10 sec", "Blinks of last 10 sec per video and threshold"]].reset_index().set_index("Stimulus").loc[order].plot(kind = "bar", title = "Mean Blink Number per Video")
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_42816\2919391923.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   blinks_left_eye_all_participants.groupby("Stimulus").mean()[["Blink Number last 10 sec", "Blinks of last 10 sec per video and threshold"]].reset_index().set_index("Stimulus").loc[order].plot(kind = "bar", title = "Mean Blink Number per Video")
# <AxesSubplot: title={'center': 'Mean Blink Number per Video'}, xlabel='Stimulus'>

# %%
order = ["vid1","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9", "vid10","vid11","vid12","vid13","vid14","vid15"]
participant = 1
blinks_left_eye_all_participants.loc[order]["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants.loc[order]["Participant"] == participant].plot(kind = "bar", title = "Participant" + str(participant) + " , Blinks of last 10 sec per video with threshold")
# Out:
# <AxesSubplot: title={'center': 'Participant1 , Blinks of last 10 sec per video with threshold'}>

# %%
order = ["vid1","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9", "vid10","vid11","vid12","vid13","vid14","vid15"]
participant = 3
blinks_left_eye_all_participants.loc[order]["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants.loc[order]["Participant"] == participant].plot(kind = "bar", title = "Participant " + str(participant) + " , Blinks of last 10 sec per video with threshold")
# Out:
# <AxesSubplot: title={'center': 'Participant 3 , Blinks of last 10 sec per video with threshold'}>

# %%
# Histogram, ho wmany videos per participant were excluded?

# %%
### Versuchsperson 1
plt.figure(1, figsize=(100,4))
for i in range(1,6):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == 1) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant 1 and Video " + str(i))

plt.show()
plt.figure(1, figsize=(100,4))
for i in range(6,11):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == 1) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant 1 and Video " + str(i))

plt.show()

plt.figure(1, figsize=(100,4))
for i in range(11,16):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == 1) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant 1 and Video " + str(i))
plt.show()

# %%
### Versuchsperson 1
plt.figure(1, figsize=(100,4))
vp = 3
for i in range(1,6):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))

plt.show()
plt.figure(1, figsize=(100,4))
for i in range(6,11):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))

plt.show()

plt.figure(1, figsize=(100,4))
for i in range(11,16):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant " + str(vp) + " and Video " + str(i))
plt.show()

# %%
### 4
### Versuchsperson 1
plt.figure(1, figsize=(100,4))
vp = 4
for i in range(1,6):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))

plt.show()
plt.figure(1, figsize=(100,4))
for i in range(6,11):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))

plt.show()

plt.figure(1, figsize=(100,4))
for i in range(11,16):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant " + str(vp) + " and Video " + str(i))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[82], line 8
#       6 plt.subplot(1,16,i)
#       7 blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
# ----> 8 data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)),
#       9 ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
#      10 plt.bar(x = blinks, height = data)
#      11 plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
### 5
### Versuchsperson 1
plt.figure(1, figsize=(100,4))
vp = 5
for i in range(1,6):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant " + str(vp) + " and Video " + str(i))

plt.show()
plt.figure(1, figsize=(100,4))
for i in range(6,11):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant " + str(vp) + " and Video " + str(i))

plt.show()

plt.figure(1, figsize=(100,4))
for i in range(11,16):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant " + str(vp) + " and Video " + str(i))
plt.show()

# %%
### Versuchsperson 1
plt.figure(1, figsize=(100,4))
vp = 6
for i in range(1,6):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))

plt.show()
plt.figure(1, figsize=(100,4))
for i in range(6,11):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))

plt.show()

plt.figure(1, figsize=(100,4))
for i in range(11,16):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant " + str(vp) + " and Video " + str(i))
plt.show()

# %%
plt.figure(1, figsize=(10,4))
vp  = 1
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
### Versuchsperson 1
plt.figure(1, figsize=(100,4))
vp = 7
for i in range(1,6):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))

plt.show()
plt.figure(1, figsize=(100,4))
for i in range(6,11):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))

plt.show()

plt.figure(1, figsize=(100,4))
for i in range(11,16):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant " + str(vp) + " and Video " + str(i))
plt.show()

# %%
### Versuchsperson 1
plt.figure(1, figsize=(100,4))
vp = 8
for i in range(1,6):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))

plt.show()
plt.figure(1, figsize=(100,4))
for i in range(6,11):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant" + str(vp) + "and Video " + str(i))

plt.show()

plt.figure(1, figsize=(100,4))
for i in range(11,16):
    plt.subplot(1,16,i)
    blinks = ["all", "with threshold", "10 sec","10 sec & threshold"]
    data = blinks_left_eye_all_participants.loc[(blinks_left_eye_all_participants["Participant"] == vp) & (blinks_left_eye_all_participants.index == "vid" + str(i)), 
    ["Blink Number whole dataframe", "Blink Number with threshold", "Blink Number last 10 sec","Blinks of last 10 sec per video and threshold"]].values[0]
    plt.bar(x = blinks, height = data)
    plt.title("Blink Number of Participant " + str(vp) + " and Video " + str(i))
plt.show()

# %%
plt.figure(1, figsize=(10,4))
vp  = 2
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 3
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 5
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 6
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 7
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 8
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 9
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 10
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 14
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 15
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 16
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(10,4))
vp  = 17
videos = ["vid1","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid2","vid3","vid4","vid5","vid6","vid7","vid8","vid9"]
blinks = blinks_left_eye_all_participants["Blinks of last 10 sec per video and threshold"].loc[blinks_left_eye_all_participants["Participant"] == vp]
plt.title("Blink number Participant "+ str(vp))
plt.bar(videos, height = blinks)
# Out:
# <BarContainer object of 16 artists>

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid1"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid2"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid3"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid4"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid5"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid6"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid7"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid8"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid9"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid10"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid11"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid12"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid13"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid14"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()

# %%
plt.figure(1, figsize=(100,4))
blinks_left_eye_all_participants.loc["vid15"].plot(x = "Participant", y = "Blinks of last 10 sec per video and threshold", kind = "bar")
plt.show()
