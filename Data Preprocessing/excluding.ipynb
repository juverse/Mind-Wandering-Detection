# %%
### dependecies ###
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import data_preparation as dp
import os

# %%
read_path_left = r"W:\WCT\04_Mind-Wandering-Labstudy\04_Daten\04_Prepared_data\00_Julia\_left_eye_all_participants_without_excluded.csv"
read_path_right = r"W:\WCT\04_Mind-Wandering-Labstudy\04_Daten\04_Prepared_data\00_Julia\_right_eye_all_participants_without_excluded.csv"

# %%
df_left = pd.read_csv(
        read_path_left,
        na_values = "-"
    )

df_right = pd.read_csv(
        read_path_right,
        na_values = "-"
    )

# %%
df_left
# Out:
#       Tracking Ratio [%] Mean Stimulus Participant  \
# 0                      85.268     vid1           1
# 1                      81.388    vid10           1
# 2                      83.450    vid11           1
# 3                      83.736    vid12           1
# 4                      87.020    vid13           1
# ...                       ...      ...         ...
# 1105                   91.360     vid5          97
# 1106                   96.044     vid6          97
# 1107                   86.734     vid7          97
# 1108                   87.880     vid8          97
# 1109                   84.449     vid9          97
#
#       Fixation Duration Mean [ms]  Fixation Duration Max [ms]  \
# 0                      252.982821                     664.007
# 1                      195.286941                     748.002
# 2                      182.768333                     555.851
# 3                      309.427091                    1004.021
# ...

# %%
df_right
# Out:
#       Tracking Ratio [%] Mean Stimulus Participant  \
# 0                      85.268     vid1           1
# 1                      81.388    vid10           1
# 2                      83.450    vid11           1
# 3                      83.736    vid12           1
# 4                      87.020    vid13           1
# ...                       ...      ...         ...
# 1105                   91.360     vid5          97
# 1106                   96.044     vid6          97
# 1107                   86.734     vid7          97
# 1108                   87.880     vid8          97
# 1109                   84.449     vid9          97
#
#       Fixation Duration Mean [ms]  Fixation Duration Max [ms]  \
# 0                      266.803333                     672.000
# 1                      195.291500                     728.016
# 2                      225.713000                     943.889
# 3                      314.333045                    1004.019
# ...

# %%
df_left_tracking_ratio_over70 = df_left.loc[df_left["Tracking Ratio [%] Mean"] >= 70.0]
df_left_tracking_ratio_over70
# Out:
#       Tracking Ratio [%] Mean Stimulus Participant  \
# 0                      85.268     vid1           1
# 1                      81.388    vid10           1
# 2                      83.450    vid11           1
# 3                      83.736    vid12           1
# 4                      87.020    vid13           1
# ...                       ...      ...         ...
# 1105                   91.360     vid5          97
# 1106                   96.044     vid6          97
# 1107                   86.734     vid7          97
# 1108                   87.880     vid8          97
# 1109                   84.449     vid9          97
#
#       Fixation Duration Mean [ms]  Fixation Duration Max [ms]  \
# 0                      252.982821                     664.007
# 1                      195.286941                     748.002
# 2                      182.768333                     555.851
# 3                      309.427091                    1004.021
# ...

# %%
df_right_tracking_ratio_over70 = df_right.loc[df_right["Tracking Ratio [%] Mean"] >= 70.0]
df_right_tracking_ratio_over70
# Out:
#       Tracking Ratio [%] Mean Stimulus Participant  \
# 0                      85.268     vid1           1
# 1                      81.388    vid10           1
# 2                      83.450    vid11           1
# 3                      83.736    vid12           1
# 4                      87.020    vid13           1
# ...                       ...      ...         ...
# 1105                   91.360     vid5          97
# 1106                   96.044     vid6          97
# 1107                   86.734     vid7          97
# 1108                   87.880     vid8          97
# 1109                   84.449     vid9          97
#
#       Fixation Duration Mean [ms]  Fixation Duration Max [ms]  \
# 0                      266.803333                     672.000
# 1                      195.291500                     728.016
# 2                      225.713000                     943.889
# 3                      314.333045                    1004.019
# ...

# %%
df_right_tracking_ratio_under70 = df_right.loc[df_right["Tracking Ratio [%] Mean"] < 70.0]
df_right_tracking_ratio_under70.groupby(["Stimulus"]).count()
# Out:
#           Tracking Ratio [%] Mean  Participant  Fixation Duration Mean [ms]  \
# Stimulus
# vid1                            1            1                            1
# vid10                          22           22                           22
# vid11                          22           22                           21
# vid12                          15           15                           15
# vid13                          21           21                           21
# vid14                          21           21                           20
# vid15                          23           23                           23
# vid2                            3            3                            3
# vid3                            6            6                            6
# vid4                            7            7                            7
# vid5                           15           15                           15
# ...

# %%
df_left_tracking_ratio_under70 = df_left.loc[df_left["Tracking Ratio [%] Mean"] < 70.0]
df_left_tracking_ratio_under70.groupby(["Stimulus"]).count()
# Out:
#           Tracking Ratio [%] Mean  Participant  Fixation Duration Mean [ms]  \
# Stimulus
# vid1                            2            2                            2
# vid10                          23           23                           23
# vid11                          22           22                           22
# vid12                          16           16                           16
# vid13                          21           21                           21
# vid14                          22           22                           22
# vid15                          23           23                           23
# vid2                            3            3                            3
# vid3                            5            5                            5
# vid4                            7            7                            7
# vid5                           16           16                           16
# ...
